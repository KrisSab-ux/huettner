# %% [markdown]
# # Projektabgabe & Bewertung
#
# ## 📅 Abgabe
# **Termin:** 17. Dezember
# **Form:** GitLab Repository
#
# ---
#
# ## 📘 Projektbericht (66% der Gesamtnote)
# **Zusammensetzung:**
# - **15%** – Scrum *(Kanban-Board mit Tickets/Tasks)*
# - **25%** – Code
# - **60%** – Dokumentation
#
# ---
#
# ## 🗣️ Präsentation (33% der Gesamtnote)
# - **Dauer:** 5–10 Minuten pro Person
# - **Termin:** ebenfalls am **17. Dezember**
#
# ---
#
# ## 📂 Dokumentationsstruktur
# Die folgenden Ordner im Repository entsprechen den geforderten **Inhaltspunkten der Dokumentation**.
# Weitere Details befinden sich **innerhalb der jeweiligen Ordner**.
