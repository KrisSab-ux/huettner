# %% [markdown]
# Favorisiert top- k(nicht k-pop) Methode. Möglich auch sind Bias/Variance Trade-off Abgleiche, Confusion Matrix, ROC Curve, Calibaration(?) Curve, Feature Importance, Black Box Explainers.
